# %% [markdown]
# Imports

# %%
import sqlite3
import pandas as pd
from mlxtend.preprocessing import TransactionEncoder
from mlxtend.frequent_patterns import apriori, association_rules
from mlxtend.frequent_patterns import apriori

# %% [markdown]
# Gather data

# %%
def getDbAsDF(conn: sqlite3.Connection, sql: str):
    cursor = conn.cursor()
    cursor.execute(sql)
    data = cursor.fetchall()

    columns = [column[0] for column in cursor.description]

    formatted_data = {}

    for i in range(len(columns)):
        dataList = []
        for j in data:
            dataList.append(j[i])
        formatted_data[columns[i]] = dataList

    df = pd.DataFrame(data=formatted_data, columns=columns)
    return df


# Connect to SQLite database
connection = sqlite3.connect(r'..\..\Data\merged.sqlite')

SQL = r"""
SELECT *
FROM order_details as OD
INNER JOIN order_header as OH ON OH.ORDER_NUMBER = OD.ORDER_NUMBER
INNER JOIN product as P ON P.PRODUCT_NUMBER = OD.PRODUCT_NUMBER
"""

Dataframe = getDbAsDF(connection, SQL)
print(Dataframe.columns)
Dataframe
# Out:
# Index(['ORDER_DETAIL_CODE', 'ORDER_NUMBER', 'PRODUCT_NUMBER', 'QUANTITY',
#        'UNIT_COST', 'UNIT_PRICE', 'UNIT_SALE_PRICE', 'ORDER_NUMBER',
#        'RETAILER_NAME', 'RETAILER_SITE_CODE', 'RETAILER_CONTACT_CODE',
#        'SALES_STAFF_CODE', 'SALES_BRANCH_CODE', 'ORDER_DATE',
#        'ORDER_METHOD_CODE', 'PRODUCT_NUMBER', 'INTRODUCTION_DATE',
#        'PRODUCT_TYPE_CODE', 'PRODUCTION_COST', 'MARGIN', 'PRODUCT_IMAGE',
#        'LANGUAGE', 'PRODUCT_NAME', 'DESCRIPTION'],
#       dtype='object')
#       ORDER_DETAIL_CODE ORDER_NUMBER PRODUCT_NUMBER  QUANTITY UNIT_COST  \
# 0                 48616         1258             17        92     60.29
# 1                 48617         1352             17       190     60.29
# 2                 48618         1544             17        82     60.29
# 3                 48619         1249             17       190     60.29
# 4                 48620         1268             17       152     60.29
# ...                 ...          ...            ...       ...       ...
# 43058            102951         8614             11        16       250
# 43059            102952         8611             11        18       250
# 43060            102953         8591             11        18       250
# 43061            102954         8619             11        18       250
# 43062            102955         8650             11        14       250
#
#       UNIT_PRICE UNIT_SALE_PRICE ORDER_NUMBER          RETAILER_NAME  \
# 0          84.41           78.37         1258  VIP Department Stores
# 1          84.41           67.08         1352      Falcon Outfitters
# 2          84.41           78.37         1544  VIP Department Stores
# 3          84.41           72.26         1249           Ultra Sports
# 4          84.41           78.05         1268      Falcon Outfitters
# ...          ...             ...          ...                    ...
# 43058        350             325         8614            Sport Jonas
# 43059        350             350         8611            Sport Jonas
# 43060        350             325         8591    Campingspecialisten
# 43061        350             350         8619            Sport Jonas
# 43062        350             350         8650    Campingspecialisten
#
#       RETAILER_SITE_CODE  ... ORDER_METHOD_CODE PRODUCT_NUMBER  \
# 0                     13  ...                 7             17
# 1                     17  ...                 2             17
# 2                     13  ...                 2             17
# 3                      4  ...                 5             17
# 4                     19  ...                 7             17
# ...                  ...  ...               ...            ...
# 43058                267  ...                 4             11
# 43059                265  ...                 5             11
# 43060                261  ...                 7             11
# 43061                268  ...                 5             11
# 43062                262  ...                 7             11
#
#       INTRODUCTION_DATE PRODUCT_TYPE_CODE PRODUCTION_COST MARGIN  \
# 0              5-3-2013                 3              60    .28
# 1              5-3-2013                 3              60    .28
# 2              5-3-2013                 3              60    .28
# 3              5-3-2013                 3              60    .28
# 4              5-3-2013                 3              60    .28
# ...                 ...               ...             ...    ...
# 43058         15-2-2011                 2             250    .28
# 43059         15-2-2011                 2             250    .28
# 43060         15-2-2011                 2             250    .28
# 43061         15-2-2011                 2             250    .28
# 43062         15-2-2011                 2             250    .28
#
#        PRODUCT_IMAGE LANGUAGE     PRODUCT_NAME  \
# 0      P17CE1SB3.jpg       EN  Hibernator Lite
# 1      P17CE1SB3.jpg       EN  Hibernator Lite
# 2      P17CE1SB3.jpg       EN  Hibernator Lite
# 3      P17CE1SB3.jpg       EN  Hibernator Lite
# 4      P17CE1SB3.jpg       EN  Hibernator Lite
# ...              ...      ...              ...
# 43058  P11CE1TN2.jpg       EN        Star Lite
# 43059  P11CE1TN2.jpg       EN        Star Lite
# 43060  P11CE1TN2.jpg       EN        Star Lite
# 43061  P11CE1TN2.jpg       EN        Star Lite
# 43062  P11CE1TN2.jpg       EN        Star Lite
#
#                                              DESCRIPTION
# 0      The Hibernator Lite is the perfect summer slee...
# 1      The Hibernator Lite is the perfect summer slee...
# 2      The Hibernator Lite is the perfect summer slee...
# 3      The Hibernator Lite is the perfect summer slee...
# 4      The Hibernator Lite is the perfect summer slee...
# ...                                                  ...
# 43058  A perfect tent for biking and hiking trips, co...
# 43059  A perfect tent for biking and hiking trips, co...
# 43060  A perfect tent for biking and hiking trips, co...
# 43061  A perfect tent for biking and hiking trips, co...
# 43062  A perfect tent for biking and hiking trips, co...
#
# [43063 rows x 24 columns]

# %% [markdown]
# Select & Format data

# %%
Data = Dataframe[["ORDER_NUMBER","PRODUCT_NAME"]]
Data = Data.T.drop_duplicates().T
Data.dropna(inplace = True)
OrderNrs = Data["ORDER_NUMBER"].unique()
Data
# Out:
#       ORDER_NUMBER     PRODUCT_NAME
# 0             1258  Hibernator Lite
# 1             1352  Hibernator Lite
# 2             1544  Hibernator Lite
# 3             1249  Hibernator Lite
# 4             1268  Hibernator Lite
# ...            ...              ...
# 43058         8614        Star Lite
# 43059         8611        Star Lite
# 43060         8591        Star Lite
# 43061         8619        Star Lite
# 43062         8650        Star Lite
#
# [43063 rows x 2 columns]

# %%
dataset = []
for number in OrderNrs:
    products = []
    FoundRows = Data.loc[Data['ORDER_NUMBER'] == number]
    for row in FoundRows["PRODUCT_NAME"]:
        products.append(row)
    dataset.append(products)
print(dataset)
# Out:
# [['Hibernator Lite', 'Polar Ice', 'Polar Wave', 'Seeker 35', 'Star Dome'], ['Hibernator Lite', 'Canyon Mule Extreme Backpack', 'Firefly 4', 'Firefly Extreme', 'EverGlow Butane', 'Husky Rope 50', 'Husky Rope 200', 'Granite Climbing Helmet', 'Granite Carabiner', 'Firefly Charger', 'Granite Chalk Bag', 'Granite Grip', 'Granite Axe', 'Mountain Man Extreme', 'BugShield Lotion', 'TrailChef Water Bag', 'Star Dome', 'Star Gazer 6'], ['Hibernator Lite', 'Hibernator', 'Hibernator Pad', 'Firefly 2'], ['Hibernator Lite', 'Canyon Mule Journey Backpack', 'Firefly Extreme', 'Calamine Relief', 'TrailChef Cup', 'TrailChef Utensils'], ['Hibernator Lite', 'Hibernator Pillow', 'Husky Harness Extreme', 'Granite Belay', 'Firefly Climbing Lamp', 'Firefly Charger', 'Firefly Rechargeable Battery', 'Granite Axe', 'Granite Extreme', 'Mountain Man Extreme', 'Edge Extreme', 'Glacier GPS', 'TrailChef Water Bag', 'TrailChef Utensils', 'Star Lite'], ['Hibernator Lite', 'Husky Rope 100', 'Husky Harness Extreme', 'Granite Carabiner', 'Granite Belay', 'Firefly Climbing Lamp', 'Firefly Charger', 'Granite Shovel', 'Granite Extreme', 'Edge Extreme', 'BugShield Extreme', 'Sun Shield', 'TrailChef Cook Set', 'Star Dome'], ['Hibernator', 'Firefly 4', 'Mountain Man Deluxe', 'TrailChef Double Flame', 'Star Gazer 3'], ['Hibernator', 'Hibernator Extreme', 'Canyon Mule Extreme Backpack', 'Firefly Extreme', 'Firefly Multi-light', 'EverGlow Lamp', 'Granite Chalk Bag', 'Seeker Extreme', 'Glacier Deluxe', 'Star Lite', 'Star Peg'], ['Hibernator', 'Canyon Mule Weekender Backpack', 'EverGlow Double', 'Mountain Man Combination', 'Mountain Man Extreme', 'Edge Extreme', 'Sun Blocker', 'Deluxe Family Relief Kit', 'TrailChef Kettle', 'TrailChef Utensils', 'Star Gazer 3'], ['Hibernator', 'Firefly 4', 'Mountain Man Deluxe', 'TrailChef Kettle'], ['Hibernator', 'Firefly Multi-light', 'EverGlow Single', 'EverGlow Double', 'Husky Rope 100', 'Granite Carabiner', 'Deluxe Family Relief Kit'], ['Hibernator', 'Firefly 2', 'Firefly Multi-light', 'Granite Grip', 'Seeker 50', 'Glacier Deluxe', 'TrailChef Canteen', 'TrailChef Kettle', 'Star Lite', 'Star Gazer 6'], ['Hibernator', 'Firefly Multi-light', 'EverGlow Single', 'EverGlow Lamp', 'Glacier GPS Extreme', 'Insect Bite Relief', 'TrailChef Canteen', 'TrailChef Kitchen Kit', 'TrailChef Cook Set', 'TrailChef Deluxe Cook Set', 'TrailChef Utensils', 'Star Gazer 6'], ['Hibernator', 'Hibernator Extreme', 'Bear Survival Edge', 'Seeker 50', 'Glacier Basic', 'TrailChef Single Flame'], ['Hibernator Extreme', 'Hibernator Camp Cot', 'Firefly Multi-light', 'EverGlow Butane', 'Husky Rope 50', 'Granite Belay', 'Firefly Charger', 'Granite Axe', 'Bear Survival Edge', 'Sun Shelter 15', 'TrailChef Canteen', 'TrailChef Kitchen Kit'], ['Hibernator Extreme', 'Hibernator Pillow', 'Canyon Mule Cooler', 'Flicker Lantern', 'Husky Rope 60', 'Husky Rope 200', 'Granite Climbing Helmet', 'Mountain Man Extreme', 'Glacier Deluxe', 'Glacier GPS Extreme', 'Sun Blocker', 'Star Lite'], ['Hibernator Extreme', 'Canyon Mule Extreme Backpack', 'EverGlow Kerosene', 'Firefly Rechargeable Battery', 'Seeker Extreme', 'BugShield Spray', 'BugShield Extreme', 'Insect Bite Relief', 'Star Gazer 3'], ['Hibernator Extreme', 'Canyon Mule Journey Backpack', 'Firefly Extreme', 'EverGlow Butane', 'Mountain Man Combination', 'Glacier Basic', 'Glacier GPS', 'BugShield Natural', 'TrailChef Double Flame', 'Star Peg', 'Hibernator Lite'], ['Hibernator Extreme', 'Hibernator Self - Inflating Mat', 'Hibernator Pillow', 'Granite Ice', 'Granite Shovel', 'Glacier GPS Extreme', 'TrailChef Kitchen Kit', 'TrailChef Cup', 'TrailChef Single Flame', 'TrailChef Utensils', 'Star Gazer 3'], ['Hibernator Extreme', 'Hibernator Pad', 'EverGlow Double', 'EverGlow Kerosene', 'Granite Pulley', 'Firefly Climbing Lamp', 'Granite Shovel', 'Star Gazer 6'], ['Hibernator Extreme', 'Canyon Mule Cooler', 'Firefly Multi-light', 'EverGlow Kerosene', 'Granite Extreme', 'Seeker 50', 'BugShield Extreme', 'TrailChef Water Bag', 'TrailChef Si ...

# %% [markdown]
# Apply apriori

# %%
tr = TransactionEncoder()
tr_arr = tr.fit(dataset).transform(dataset)
FormatDF = pd.DataFrame(tr_arr, columns=tr.columns_)
FormatDF
# Out:
#       Aloe Relief  Bear Edge  Bear Survival Edge  Blue Steel Max Putter  \
# 0           False      False               False                  False
# 1           False      False               False                  False
# 2           False      False               False                  False
# 3           False      False               False                  False
# 4           False      False               False                  False
# ...           ...        ...                 ...                    ...
# 5355        False      False               False                  False
# 5356        False       True               False                  False
# 5357        False      False               False                  False
# 5358        False      False               False                  False
# 5359        False      False               False                  False
#
#       Blue Steel Putter  BugShield Extreme  BugShield Lotion  \
# 0                 False              False             False
# 1                 False              False              True
# 2                 False              False             False
# 3                 False              False             False
# 4                 False              False             False
# ...                 ...                ...               ...
# 5355              False              False             False
# 5356              False              False              True
# 5357              False               True              True
# 5358              False              False             False
# 5359              False              False             False
#
#       BugShield Lotion Lite  BugShield Natural  BugShield Spray  ...  \
# 0                     False              False            False  ...
# 1                     False              False            False  ...
# 2                     False              False            False  ...
# 3                     False              False            False  ...
# 4                     False              False            False  ...
# ...                     ...                ...              ...  ...
# 5355                  False              False            False  ...
# 5356                  False               True             True  ...
# 5357                  False              False             True  ...
# 5358                   True              False            False  ...
# 5359                   True              False            False  ...
#
#       TrailChef Canteen  TrailChef Cook Set  TrailChef Cup  \
# 0                 False               False          False
# 1                 False               False          False
# 2                 False               False          False
# 3                 False               False           True
# 4                 False               False          False
# ...                 ...                 ...            ...
# 5355              False               False          False
# 5356              False               False          False
# 5357              False               False          False
# 5358              False               False          False
# 5359              False               False          False
#
#       TrailChef Deluxe Cook Set  TrailChef Double Flame  TrailChef Kettle  \
# 0                         False                   False             False
# 1                         False                   False             False
# 2                         False                   False             False
# 3                         False                   False             False
# 4                         False                   False             False
# ...                         ...                     ...               ...
# 5355                      False                   False             False
# 5356                      False                   False             False
# 5357                      False                   False             False
# 5358                      False                   False             False
# 5359                      False                   False             False
#
#       TrailChef Kitchen Kit  TrailChef Single Flame  TrailChef Utensils  \
# 0                     False                   False               False
# 1                     False                   False               False
# 2                     False                   False               False
# 3                     False                   False                True
# 4                     False                   False                True
# ...                     ...                     ...                 ...
# 5355                  False                   False               False
# 5356                  False                   False               False
# 5357                  False                   False               False
# 5358                  False                   False               False
# 5359                  False                   False               False
#
#       TrailChef Water Bag
# 0                   False
# 1                    True
# 2                   False
# 3                   False
# 4                    True
# ...                   ...
# 5355                False
# 5356                False
# 5357                False
# 5358                False
# 5359                False
#
# [5360 rows x 115 columns]

# %%
frequent_itemsets = apriori(FormatDF, min_support = 0.01, use_colnames = True, verbose=1) #0.1, 0.001 barely works w/32gb
frequent_itemsets = frequent_itemsets.sort_values(by=['support'], ascending=False)
frequent_itemsets
# Out:
# Processing 193413 combinations | Sampling itemset size 3
#        support                               itemsets
# 11    0.106903                 (Canyon Mule Carryall)
# 102   0.104104                       (Sun Shelter 30)
# 24    0.101119                          (Double Edge)
# 64    0.099067                      (Hibernator Lite)
# 31    0.097948                            (Firefly 2)
# ...        ...                                    ...
# 1790  0.010075              (Star Dome, Star Gazer 3)
# 1061  0.010075  (Firefly Multi-light, Hibernator Pad)
# 1788  0.010075      (Single Edge, TrailChef Utensils)
# 1052  0.010075   (Firefly Multi-light, Glacier Basic)
# 854   0.010075       (Firefly Multi-light, Firefly 4)
#
# [1907 rows x 2 columns]

# %% [markdown]
# Support (item) = (Transactions relating item) / (Total transactions)
# Confidence = (Transactions relating both item1 and item2) / (Total transactions involving item1)
#
# Apriori is traag wanneer grote datasets in memory geladen moeten worden en de min_support klein is, gelukkig is deze dataset niet al te groot
